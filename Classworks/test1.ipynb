# %%
from Library_Classworks import *
import numpy as np

# %%
def g(x):
    return 20

def a(t):
    return 20 + 5*np.sin(2*np.pi*t/24)

def b(t):
    return 20

# %%
import matplotlib.pyplot as plt
for i in [6]:
    xlist,Tlist,tlist = crank_nicolson(g,a,b,0,10,0,24,500,10000,i,k=2)
    plt.plot(Tlist,xlist,label=str(i))
plt.legend()
plt.gca().invert_yaxis()
plt.ylim(1.5,0)
plt.xlim(14,26)
plt.show()

# %%
import numpy as np
np.exp(np.pi/7j)
for i in range(10):
    print(np.exp(2*i*np.pi/1j-np.pi/10j))
# Out:
# (0.9510565162951535+0.3090169943749474j)
# (0.9510565162951535+0.3090169943749477j)
# (0.9510565162951534+0.3090169943749479j)
# (0.9510565162951528+0.3090169943749498j)
# (0.9510565162951528+0.30901699437495006j)
# (0.9510565162951526+0.3090169943749503j)
# (0.9510565162951525+0.3090169943749505j)
# (0.9510565162951525+0.3090169943749507j)
# (0.9510565162951524+0.30901699437495095j)
# (0.9510565162951523+0.3090169943749512j)
